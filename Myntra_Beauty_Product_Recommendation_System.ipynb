# %% [markdown]
# **Members**:
#
#   *A.V.N.M.Hemateja*
#
#   *S.Abishek Sriram*
#
# **College:**
#
# *Vellore Institute of Technology, Chennai*

# %% [markdown]
# # Myntra Beauty Product Recommendation System

# %%
#connect to Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Code works without an error when we use tensorflow above 2 version
import tensorflow as tf

# %%
# Importing libraries
import pandas as pd
import numpy as np
from sklearn.manifold import TSNE

# Loading the dataset
df = pd.read_csv('/content/drive/MyDrive/Myntra_Hackerramp/Beauty_Recommendation/Beauty_Recommendation_Dataset/cosmetics_final.csv')

# if the user picks Moisturizer and user has dry skin
# Filtering for moisturizers
moisturizers = df.query('Label =="Moisturizer"')

# Filtering for dry skin
moisturizers_dry = moisturizers.query('Dry==1')

# Reseting index
moisturizers_dry = moisturizers_dry.reset_index(drop=True)

# %%
#This is the Ideal Product which is recommended by experts based on the ingredients required for that particular skin type
#We are adding this to the dataframe so that we can plot this also as a point in the grid to find similar products with these ingredients
moisturizers_dry.loc[len(moisturizers_dry.index)] = ["Required_Ingredients","","",0,5,"Water,Sodium Methyl Cocoyl Taurate,Cocamidopropyl Betaine,Peg-2 Laurate,Glycol Distearate,Propylene Glycol Laurate,Glycerin,Dipropylene Glycol,Polyquaternium-10,Phenoxyethanol",0,1,0,0,0]

# %%
# Initializing dictionary, list, and initial index
ingredient_idx = {}
corpus = []
idx = 0

# Loop to tokenize the ingredients
for i in range(len(moisturizers_dry)):    
    ingredients = moisturizers_dry['Ingredients'][i]
    ingredients_lower = ingredients.lower()
    tokens = ingredients_lower.split(', ')
    corpus.append(tokens)
    for ingredient in tokens:
        if ingredient not in ingredient_idx:
            ingredient_idx[ingredient] = idx
            idx += 1

# %%
# Storing the number of items and ingredients in the dataframe
M = moisturizers_dry['Name'].shape[0]
N = len(ingredient_idx)

# Initialize a matrix with zeros for filling them
A = np.zeros((M,N))

# %%
# Defining the Encoding function for converting all ingredients to numbers associated using ingredient_idx dictionary
def Encode(tokens):
    x = np.zeros(N)
    for ingredient in tokens:
        # Get the index for each ingredient
        idx = ingredient_idx[ingredient]
        # Put 1 at the corresponding indices
        x[idx] =1 
    return x

# %%
# Making the Document Term Matrix (DTM)
i = 0
for tokens in corpus:
    A[i, :] = Encode(tokens)
    i+=1

# %%
# Reducing the dimension using TSNE model(T-distributed Stochastic Neighbor Embedding)
# initializing the model with required arguments and also providing metric for distance(euclidean) - sqrt((x2-x1)^2 + (y2-y1)^2)
model = TSNE(n_components= 2, learning_rate=200, random_state=42,metric='euclidean')
#transforming the A matrix to 2D features
tsne_features = model.fit_transform(A)

# Creating X and Y columns to store the X-axis and Y-axis values for getting similar (nearest) points 
moisturizers_dry['X'] = tsne_features[:,0]
moisturizers_dry['Y'] = tsne_features[:,1]

# %%
#Defining function for sorting list consisting of tuple (like (var1,var2)) according second variable
def sortSecond(val):
    return val[1]

# %%
#importing math library for finding euclidean distance
import math
#Getting the X and Y values of reference product recommeded by expert (Required_Ingredients)
Reference_X_Y = moisturizers_dry[moisturizers_dry['Label'] == "Required_Ingredients"]
Reference_X=Reference_X_Y.X.values[0]
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                       -6.84756
#   Y                                                       -6.69557
#   Name: 155, dtype: object, 7.239861109122021),
#  (Label                                                Moisturizer
#   Brand                                                JOSIE MARAN
#   Name                   Argan Infinity Cream Intensive Creamy Oil
#   Price                                                         28
#   Rank                                                         4.5
#   Ingredients    -100 Percent Pure Argan Oil: Nourishes and pro...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           0
#   Sensitive                                                      1
#   X                                                        1.26287
#   Y                                                       -8.22805
#   Name: 150, dtype: object, 7.5214308739831175),
#  (Label                                                Moisturizer
#   Brand                                                   GUERLAIN
#   Name                             Abeille Royale Youth Watery Oil
#   Price                                                         50
#   Rank                                                         4.1
#   Ingredients    -Black Bee Honey -Ouessant Honey: Repairs skin...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      0
#   X                                                       -5.05242
#   Y                                                        5.44474
#   Name: 98, dtype: object, 7.539405597961026),
#  (Label                                                Moisturizer
#   Brand                                                  HERBIVORE
#   Name                        Phoenix Cell Regenerating Facial Oil
#   Price                                                         88
#   Rank                                                         4.5
#   Ingredients    Simmondsia Chinensis (Jojoba) Seed Oil, Rosa C...
#   Combination                                                    0
#   Dry                                                            1
#   Normal                                                         0
#   Oily                                                           0
#   Sensitive                                                      1
#   X                                                         3.6476
#   Y                                                        3.84013
#   Name: 73, dtype: object, 7.638409273954364),
#  (Label                                                Moisturizer
#   Brand                                                   GUERLAIN
#   Name                                   Lingerie de Peau BB Cream
#   Price                                                         54
#   Rank                                                         4.3
#   Ingredients    -Titanium Dioxide 3.55%: Sunscreen. -Octinoxat...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                       -10.4704
#   Y                                                      -0.335082
#   Name: 138, dtype: object, 8.632733394657121),
#  (Label                                                Moisturizer
#   Brand                                                      SK-II
#   Name                               Facial Treatment Essence Mini
#   Price                                                         99
#   Rank                                                         4.1
#   Ingredients    Galactomyces Ferment Filtrate (Pitera), Butyle...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                        11.2003
#   Y                                                       -1.29135
#   Name: 24, dtype: object, 13.105084936191318),
#  (Label                                                Moisturizer
#   Brand                                                      SK-II
#   Name                                    Facial Treatment Essence
#   Price                                                        179
#   Rank                                                         4.1
#   Ingredients    Galactomyces Ferment Filtrate (Pitera), Butyle...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                        10.1846
#   Y                                                       -7.93085
#   Name: 1, dtype: object, 13.737447358624433),
#  (Label                                                Moisturizer
#   Brand                                                  BIOSSANCE
#   Name                               Squalane + Vitamin C Rose Oil
#   Price                                                         72
#   Rank                                                         4.4
#   Ingredients    Squalane, Pistacia Lentiscus (Mastic) Gum, Ros...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                       -3.52764
#   Y                                                       -15.0954
#   Name: 35, dtype: object, 13.785323329242146),
#  (Label                                                Moisturizer
#   Brand                                                   CAUDALIE
#   Name                                                 Grape Water
#   Price                                                         10
#   Rank                                                         4.5
#   Ingredients    Vitis Vinifera (Grape) Fruit Water*, Vitis Vin...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                       -11.6802
#   Y                                                       -12.3318
#   Name: 32, dtype: object, 14.660908679194636),
#  (Label                                                Moisturizer
#   Brand                                                  HERBIVORE
#   Name             Rose Hibiscus Coconut Water Hydrating Face Mist
#   Price                                                         32
#   Rank                                                         4.1
#   Ingredients    Water, Aloe Barbadensis Leaf Water, Rosa Damas...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                       -13.6809
#   Y                                                         8.4484
#   Name: 156, dtype: object, 15.355664531565877),
#  (Label                                                Moisturizer
#   Brand                                                      TARTE
#   Name           BB Tinted Treatment 12-Hour Primer Broad Spect...
#   Price                                                         37
#   Rank                                                         4.3
#   Ingredients    Cyclopentasiloxane, Isododecane, Mica, Polysil...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      0
#   X                                                        0.15804
#   Y                                                        13.8556
#   Name: 36, dtype: object, 15.400297568142582),
#  (Label                                                Moisturizer
#   Brand                                               SUNDAY RILEY
#   Name                       Juno Antioxidant + Superfood Face Oil
#   Price                                                         72
#   Rank                                                         4.4
#   Ingredients    Rubus Fruticosus (Cold Pressed Blackberry) See...
#   Combination                                                    0
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           0
#   Sensitive                                                      1
#   X                                                       -17.6076
#   Y                                                       -5.94294
#   Name: 50, dtype: object, 16.34557054161074),
#  (Label                                                Moisturizer
#   Brand                                                   CAUDALIE
#   Name                             Vine[activ] Overnight Detox Oil
#   Price                                                         50
#   Rank                                                         4.5
#   Ingredients    Caprylic/Capric Triglyceride, Vitis Vinifera (...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                        9.64716
#   Y                                                        10.4115
#   Name: 122, dtype: object, 16.52540068041758),
#  (Label                                                Moisturizer
#   Brand                                                    LANEIGE
#   Name                              Water Bank Dual Layer Face Oil
#   Price                                                         38
#   Rank                                                           5
#   Ingredients    Water, Caprylic/Capric Triglyceride, Squalane,...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           0
#   Sensitive                                                      0
#   X                                                        6.66845
#   Y                                                       -17.5989
#   Name: 141, dtype: object, 18.322247410453137),
#  (Label                                                Moisturizer
#   Brand                                               AMOREPACIFIC
#   Name                              Vintage Single Extract Essence
#   Price                                                        145
#   Rank                                                         4.5
#   Ingredients    Water, Propanediol, Glycerin, Camellia Sinensi...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      0
#   X                                                       -8.91259
#   Y                                                        15.5688
#   Name: 56, dtype: object, 18.364625523048854),
#  (Label                                                Moisturizer
#   Brand                                                     TATCHA
#   Name                          The Essence Plumping Skin Softener
#   Price                                                         95
#   Rank                                                         4.4
#   Ingredients    Saccharomyces/Camellia Sinensis Leaf/Cladosiph...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                       -19.8347
#   Y                                                        2.76871
#   Name: 87, dtype: object, 18.409942663010156),
#  (Label                                                Moisturizer
#   Brand                                                MILK MAKEUP
#   Name                                               Cooling Water
#   Price                                                         24
#   Rank                                                         3.8
#   Ingredients    Water, Butylene Glycol, Bis-PEG-18 Methyl Ethe...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                        18.8663
#   Y                                                        4.39254
#   Name: 117, dtype: object, 21.56486297424113),
#  (Label                                                Moisturizer
#   Brand                                         KIEHL'S SINCE 1851
#   Name                               Midnight Recovery Concentrate
#   Price                                                         47
#   Rank                                                         4.4
#   Ingredients    Caprylic/Capric Triglyceride Dicaprylyl Carbon...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                       -11.7732
#   Y                                                       -22.0657
#   Name: 7, dtype: object, 22.895790474271127),
#  (Label                                                Moisturizer
#   Brand                                                      SK-II
#   Name                                      Cellumination Cream EX
#   Price                                                        160
#   Rank                                                         4.3
#   Ingredients    Water, Galactomyces Ferment Filtrate (Pitera),...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                        17.4463
#   Y                                                       -13.7524
#   Name: 121, dtype: object, 22.95387809794119),
#  (Label                                                Moisturizer
#   Brand                                                JOSIE MARAN
#   Name                                         Argan Cleansing Oil
#   Price                                                         32
#   Rank                                                         4.1
#   Ingredients    Helianthus Annuus (Sunflower) Seed Oil**, Poly...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                       -20.6937
#   Y                                                       -14.9678
#   Name: 127, dtype: object, 23.17252008866407),
#  (Label                                                Moisturizer
#   Brand                                         KIEHL'S SINCE 1851
#   Name                                  Daily Reviving Concentrate
#   Price                                                         47
#   Rank                                                         4.7
#   Ingredients    Caprylic/Capric Triglyceride, Dicaprylyl Ether...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                      -0.692456
#   Y                                                       -24.8326
#   Name: 78, dtype: object, 23.457920377082008),
#  (Label                                                Moisturizer
#   Brand                                                      FRESH
#   Name                                             Crème Ancienne®
#   Price                                                        290
#   Rank                                                         4.4
#   Ingredients    Limnanthes Alba (Meadowfoam) Seed Oil, Water, ...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                        22.4099
#   Y                                                       -5.13928
#   Name: 58, dtype: object, 24.59914131769949),
#  (Label                                                Moisturizer
#   Brand                                                   SMASHBOX
#   Name           Camera Ready CC Cream Broad Spectrum SPF 30 Da...
#   Price                                                         42
#   Rank                                                         3.9
#   Ingredients    Octinoxate 7.50%, Octisalate 4.00%, Oxybenzone...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                        8.15996
#   Y                                                         22.389
#   Name: 109, dtype: object, 25.835870552092906),
#  (Label                                                Moisturizer
#   Brand                                              KORA ORGANICS
#   Name                                          Noni Glow Face Oil
#   Price                                                         68
#   Rank                                                         4.3
#   Ingredients    Rosa Canina Fruit Oil*, Simmondsia Chinensis (...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                       -27.5745
#   Y                                                       -5.08568
#   Name: 91, dtype: object, 25.93262168886955),
#  (Label                                                Moisturizer
#   Brand                                                     TATCHA
#   Name                        Pure One Step Camellia Cleansing Oil
#   Price                                                         48
#   Rank                                                         4.5
#   Ingredients    Cetyl Ethylhexanoate, Oryza Sativa (Rice) Bran...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                       -24.8222
#   Y                                                        11.2606
#   Name: 20, dtype: object, 26.18533228601456),
#  (Label                                                Moisturizer
#   Brand                                           FIRST AID BEAUTY
#   Name                               Ultra Repair® Hydrating Serum
#   Price                                                         36
#   Rank                                                         4.2
#   Ingredients    Water, Glycerin, Soluble Collagen, Methyl Gluc...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                       -5.79688
#   Y                                                         24.603
#   Name: 95, dtype: object, 26.29864671651553),
#  (Label                                                Moisturizer
#   Brand                                         KIEHL'S SINCE 1851
#   Name                                    Ultra Facial Moisturizer
#   Price                                                         29
#   Rank                                                         3.9
#   Ingredients    Water Squalane, Glycerin, Peg-100 Stearate, Gl...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                         18.825
#   Y                                                        15.2641
#   Name: 128, dtype: object, 26.60069092701255),
#  (Label                                                Moisturizer
#   Brand                                               AMOREPACIFIC
#   Name                                             Treatment Toner
#   Price                                                         50
#   Rank                                                         4.4
#   Ingredients    Panax Ginseng Root Extract, Butylene Glycol, W...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                       -17.3022
#   Y                                                        21.1369
#   Name: 131, dtype: object, 27.299723030703465),
#  (Label                                                Moisturizer
#   Brand                                                GLOW RECIPE
#   Name                               Watermelon Glow Sleeping Mask
#   Price                                                         45
#   Rank                                                         4.1
#   Ingredients    Water, Sodium Hyaluronate, Glycerin, Caulerpa ...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                        14.1937
#   Y                                                       -24.7965
#   Name: 29, dtype: object, 28.394794324054235),
#  (Label                                                Moisturizer
#   Brand                                                      GO-TO
#   Name                                                   Face Hero
#   Price                                                         34
#   Rank                                                         4.8
#   Ingredients    Almond Oil, Jojoba Oil, Macadamia Oil, Brazil ...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                       -22.0659
#   Y                                                       -25.2816
#   Name: 165, dtype: object, 31.24956790808985),
#  (Label                                                Moisturizer
#   Brand                                                     TATCHA
#   Name                                    Gold Camellia Beauty Oil
#   Price                                                         95
#   Rank                                                         4.6
#   Ingredients    Caprylic/Capric Triglyceride, Ethylhexyl Palmi...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                       -32.7107
#   Y                                                        5.88984
#   Name: 107, dtype: object, 31.65849688087706),
#  (Label                                                Moisturizer
#   Brand                                                     KORRES
#   Name                  Wild Rose Vitamin C Active Brightening Oil
#   Price                                                         54
#   Rank                                                         4.4
#   Ingredients    Isoamyl Laurate, Caprylic/Capric Triglyceride,...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                       -7.53181
#   Y                                                       -33.3792
#   Name: 115, dtype: object, 32.4647168787341),
#  (Label                                                Moisturizer
#   Brand                                        YOUTH TO THE PEOPLE
#   Name                               Superberry Hydrate + Glow Oil
#   Price                                                         44
#   Rank                                                         4.8
#   Ingredients    Helianthus Annuus (Sunflower) Seed Oil*, Dicap...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           0
#   Sensitive                                                      1
#   X                                                       -31.6833
#   Y                                                        -15.495
#   Name: 81, dtype: object, 32.943714252926235),
#  (Label                                                Moisturizer
#   Brand                                         KIEHL'S SINCE 1851
#   Name                             Ultra Facial Deep Moisture Balm
#   Price                                                         29
#   Rank                                                         4.7
#   Ingredients    Water, Glycerin, Shea Butter, Glyceryl Stearat...
#   Combination                                                    0
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           0
#   Sensitive                                                      0
#   X                                                        29.9016
#   Y                                                         8.1484
#   Name: 161, dtype: object, 33.21000440814713),
#  (Label                                                Moisturizer
#   Brand                                           FIRST AID BEAUTY
#   Name                               Ultra Repair Face Moisturizer
#   Price                                                         24
#   Rank                                                         4.2
#   Ingredients    Water, Glyceryl Stearate Se, Glycerin, Capryli...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                        1.88005
#   Y                                                        31.7074
#   Name: 97, dtype: object, 33.3288900794872),
#  (Label                                                Moisturizer
#   Brand                                                   SMASHBOX
#   Name                                   Photo Finish Primer Water
#   Price                                                         32
#   Rank                                                         4.1
#   Ingredients    Water, Butylene Glycol, Caffeine, Magnesium Ch...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                        27.6673
#   Y                                                       -16.8223
#   Name: 84, dtype: object, 33.34886929848762),
#  (Label                                                Moisturizer
#   Brand                                                    FARMACY
#   Name           Honey Savior All-in-One Skin Repair Salve with...
#   Price                                                         34
#   Rank                                                         4.5
#   Ingredients    Ricinus Communis (Castor) Seed Oil, Hydroxyste...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           0
#   Sensitive                                                      1
#   X                                                        4.64328
#   Y                                                       -34.7918
#   Name: 129, dtype: object, 34.021818703131316),
#  (Label                                                Moisturizer
#   Brand                                                  BIOSSANCE
#   Name                        Squalane + Probiotic Gel Moisturizer
#   Price                                                         52
#   Rank                                                         4.4
#   Ingredients    Water, Squalane, Glycerin, Dimethicone, Pentyl...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                        19.5565
#   Y                                                         26.533
#   Name: 88, dtype: object, 35.230025598836704),
#  (Label                                                Moisturizer
#   Brand                                                   CLINIQUE
#   Name           Limited Edition Dramatically Different Moistur...
#   Price                                                         39
#   Rank                                                           0
#   Ingredients    Water, Mineral Oil/Paraffinum Liquidum/Huile M...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         0
#   Oily                                                           0
#   Sensitive                                                      0
#   X                                                       -28.6377
#   Y                                                        22.3046
#   Name: 157, dtype: object, 35.73322258304945),
#  (Label                                                Moisturizer
#   Brand                                                    LANEIGE
#   Name                                          Water Bank Essence
#   Price                                                         36
#   Rank                                                         4.7
#   Ingredients    Water, Glycerin, Butylene Glycol, Glycereth-26...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                        33.8366
#   Y                                                       -4.35148
#   Name: 63, dtype: object, 35.86204368203838),
#  (Label                                                Moisturizer
#   Brand                                               SUNDAY RILEY
#   Name                                     Luna Sleeping Night Oil
#   Price                                                        105
#   Rank                                                         4.1
#   Ingredients    Persea Gratissima (Extra Virgin, Cold Pressed ...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                       -38.9571
#   Y                                                       -5.12381
#   Name: 8, dtype: object, 37.23881036881226),
#  (Label                                                Moisturizer
#   Brand                                           FIRST AID BEAUTY
#   Name                       Ultra Repair® Cream Intense Hydration
#   Price                                                         30
#   Rank                                                         4.6
#   Ingredients    Water, Stearic Acid, Glycerin, C12-15 Alkyl Be...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                       -8.34685
#   Y                                                        35.4549
#   Name: 11, dtype: object, 37.41964703443794),
#  (Label                                                Moisturizer
#   Brand                                                   SMASHBOX
#   Name                                     Photo Finish Primerizer
#   Price                                                         42
#   Rank                                                         4.1
#   Ingredients    Water, Glycerin, Dimethicone, Isopropyl Isoste...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      0
#   X                                                        30.0612
#   Y                                                        20.1851
#   Name: 89, dtype: object, 38.574185383634656),
#  (Label                                                Moisturizer
#   Brand                                                  BIOSSANCE
#   Name                        Squalane + Antioxidant Cleansing Oil
#   Price                                                         30
#   Rank                                                         4.4
#   Ingredients    Caprylic/Capric Triglyceride, Polyglyceryl-2 C...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                       -18.2904
#   Y                                                       -36.3784
#   Name: 144, dtype: object, 38.62094588368112),
#  (Label                                                Moisturizer
#   Brand                                                 SUPERGOOP!
#   Name           CC Cream Daily Correct Broad Spectrum SPF 35+ ...
#   Price                                                         34
#   Rank                                                         4.4
#   Ingredients    Water, Cyclopentasiloxane, Propanediol, Dimeth...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                       -21.2924
#   Y                                                        32.6149
#   Name: 110, dtype: object, 39.15755789735111),
#  (Label                                                Moisturizer
#   Brand                                               OLEHENRIKSEN
#   Name                      Invigorating Night Transformation™ Gel
#   Price                                                         48
#   Rank                                                         4.3
#   Ingredients    Water, Glycolic Acid, Glycerin, Chondrus Crisp...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                        18.9837
#   Y                                                       -34.6518
#   Name: 74, dtype: object, 39.263138708813685),
#  (Label                                                Moisturizer
#   Brand                                         KIEHL'S SINCE 1851
#   Name                       Ultra Facial Overnight Hydrating Mask
#   Price                                                         35
#   Rank                                                         4.4
#   Ingredients    Water Glycerin, Propylene Glycol, Squalane, Sh...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                        12.9589
#   Y                                                        36.3336
#   Name: 120, dtype: object, 40.56093971244701),
#  (Label                                                Moisturizer
#   Brand                                               ESTÉE LAUDER
#   Name           Advanced Night Repair Intensive Recovery Ampoules
#   Price                                                        115
#   Rank                                                         4.9
#   Ingredients    Advanced Night Rpr Int Rcv Ampoule Division: E...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                       -34.1809
#   Y                                                       -26.9332
#   Name: 136, dtype: object, 41.15115381895451),
#  (Label                                                Moisturizer
#   Brand                                               SUNDAY RILEY
#   Name                        Tidal Brightening Enzyme Water Cream
#   Price                                                         65
#   Rank                                                         4.2
#   Ingredients    Water, Hydrolyzed Jojoba Esters, Glycerin, Cap...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           0
#   Sensitive                                                      1
#   X                                                       -39.7161
#   Y                                                        15.6378
#   Name: 31, dtype: object, 41.475517161498935),
#  (Label                                                Moisturizer
#   Brand                                         REN CLEAN SKINCARE
#   Name                           Evercalm™ Overnight Recovery Balm
#   Price                                                         48
#   Rank                                                         4.9
#   Ingredients    Coco-Caprylate/Caprate, Glycerin, Water, Almon...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                        30.8825
#   Y                                                       -29.1743
#   Name: 94, dtype: object, 42.9657694941081),
#  (Label                                                Moisturizer
#   Brand                                                    CLARINS
#   Name           Extra-Firming Neck Anti-Wrinkle Rejuvenating C...
#   Price                                                         90
#   Rank                                                         4.1
#   Ingredients    Water, Dimethicone, Cetearyl Isononanoate, Gly...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                       -3.52859
#   Y                                                       -46.2974
#   Name: 123, dtype: object, 44.92077685425865),
#  (Label                                                Moisturizer
#   Brand                                                      SK-II
#   Name                                GenOptics Aura Essence Serum
# ...
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                       -99.6658
#   Y                                                       -48.9344
#   Name: 60, dtype: object, 108.7025836261176),
#  (Label                                                Moisturizer
#   Brand                                                   SHISEIDO
#   Name           White Lucent All Day Brightener Broad Spectrum...
#   Price                                                         62
#   Rank                                                         4.6
#   Ingredients    Water, Sd Alcohol 40-B, Dimethicone, Dipropyle...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           0
#   Sensitive                                                      0
#   X                                                        63.8578
#   Y                                                       -88.2958
#   Name: 162, dtype: object, 108.9701526254299),
#  (Label                                                Moisturizer
#   Brand                                                  DR. JART+
#   Name                                            Ceramidin™ Cream
#   Price                                                         48
#   Rank                                                         4.6
#   Ingredients    Water, Glycerin, Dipropylene Glycol, Cetearyl ...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           0
#   Sensitive                                                      1
#   X                                                       -107.637
#   Y                                                        26.6048
#   Name: 49, dtype: object, 109.38016745870274),
#  (Label                                                Moisturizer
#   Brand                                               IT COSMETICS
#   Name               Your Skin But Better™ CC+™ Cream with SPF 50+
#   Price                                                         38
#   Rank                                                         4.1
#   Ingredients    Water, Snail Secretion Filtrate, Phenyl Trimet...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                        96.9471
#   Y                                                       -49.5293
#   Name: 4, dtype: object, 109.94296199126016),
#  (Label                                                Moisturizer
#   Brand                                                     KORRES
#   Name           Wild Rose + Vitamin C Advanced Brightening Sle...
#   Price                                                         48
#   Rank                                                         4.4
#   Ingredients    Water, Glycerin, Glyceryl Stearate Citrate, Di...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                        15.8462
#   Y                                                       -110.705
#   Name: 79, dtype: object, 110.73066217967008),
#  (Label                                                Moisturizer
#   Brand                                                      BELIF
#   Name                            The True Cream Moisturizing Bomb
#   Price                                                         38
#   Rank                                                         4.6
#   Ingredients    Water, Glycerin, Cyclohexasiloxane, Hydrogenat...
#   Combination                                                    0
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           0
#   Sensitive                                                      0
#   X                                                       -26.8872
#   Y                                                        106.853
#   Name: 16, dtype: object, 111.10462965723428),
#  (Label                                                Moisturizer
#   Brand                                               OLEHENRIKSEN
#   Name                     Goodnight Glow Retin-ALT Sleeping Crème
#   Price                                                         55
#   Rank                                                         4.3
#   Ingredients    Water, Glycerin, Vitis Vinifera (Grape) Seed O...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      0
#   X                                                        106.204
#   Y                                                       -27.5253
#   Name: 27, dtype: object, 111.21918810910256),
#  (Label                                                Moisturizer
#   Brand                                                   GLAMGLOW
#   Name                             THIRSTYMUD™ Hydrating Treatment
#   Price                                                         59
#   Rank                                                         4.3
#   Ingredients    Water, Caprylic/Capric Triglyceride, Glycerin,...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      0
#   X                                                       -50.9183
#   Y                                                        98.5088
#   Name: 53, dtype: object, 111.2894234169857),
#  (Label                                                Moisturizer
#   Brand                                                  DR. JART+
#   Name           Cicapair ™ Tiger Grass Color Correcting Treatm...
#   Price                                                         52
#   Rank                                                         4.2
#   Ingredients    Water, Centella Asiatica Leaf Water, Isononyl ...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                         24.706
#   Y                                                        108.681
#   Name: 42, dtype: object, 113.25711280704755),
#  (Label                                                Moisturizer
#   Brand                                               IT COSMETICS
#   Name           Your Skin But Better CC+ Cream Oil-Free Matte ...
#   Price                                                         38
#   Rank                                                         3.9
#   Ingredients    Water, Dimethicone, Butylene Glycol Dicaprylat...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      0
#   X                                                       -90.3314
#   Y                                                          74.69
#   Name: 21, dtype: object, 116.66169271235502),
#  (Label                                                Moisturizer
#   Brand                                                      MURAD
#   Name                                  Nutrient-Charged Water Gel
#   Price                                                         60
#   Rank                                                         4.6
#   Ingredients    Water, Dimethicone, Glycerin, Propanediol, Sac...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                       -17.1352
#   Y                                                       -118.127
#   Name: 137, dtype: object, 117.71075437791661),
#  (Label                                                Moisturizer
#   Brand                                                     LA MER
#   Name                                        Crème de la Mer Mini
#   Price                                                         85
#   Rank                                                         4.1
#   Ingredients    Algae (Seaweed) Extract, Mineral Oil, Petrolat...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                       -122.003
#   Y                                                        -2.6774
#   Name: 14, dtype: object, 120.10574896919425),
#  (Label                                                Moisturizer
#   Brand                                                    ORIGINS
#   Name           GinZing™ SPF 40 Energy-Boosting Tinted Moistur...
#   Price                                                         39
#   Rank                                                           4
#   Ingredients    Octinoxate 7.5%, Octisalate 2.0%, Octocrylene ...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      0
#   X                                                        92.3867
#   Y                                                       -77.6567
#   Name: 111, dtype: object, 121.26408464959712),
#  (Label                                                Moisturizer
#   Brand                                                   CAUDALIE
#   Name                                           Premier Cru Cream
#   Price                                                        140
#   Rank                                                         4.4
#   Ingredients    Water, Butylene Glycol*, Caprylic/Capric Trigl...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                        65.6918
#   Y                                                        100.991
#   Name: 112, dtype: object, 122.69598264019588),
#  (Label                                                Moisturizer
#   Brand                                                     LA MER
#   Name                                             Crème de la Mer
#   Price                                                        175
#   Rank                                                         4.1
#   Ingredients    Algae (Seaweed) Extract, Mineral Oil, Petrolat...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                       -125.351
#   Y                                                       -7.81347
#   Name: 0, dtype: object, 123.61286979812894),
#  (Label                                                Moisturizer
#   Brand                                                   CAUDALIE
#   Name                                      Premier Cru Rich Cream
#   Price                                                        140
#   Rank                                                         4.5
#   Ingredients    Water, Coco-Caprylate/Caprate*, Butylene Glyco...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                        72.5038
#   Y                                                        100.817
#   Name: 153, dtype: object, 126.43630496213585),
#  (Label                                                Moisturizer
#   Brand                                                     LA MER
#   Name                                The Moisturizing Soft Lotion
#   Price                                                        270
#   Rank                                                         3.6
#   Ingredients    Algae (Seaweed) Extract, Petrolatum, Isocetyl ...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                         129.71
#   Y                                                        15.7569
#   Name: 100, dtype: object, 132.7288706475835),
#  (Label                                                Moisturizer
#   Brand                                                     LA MER
#   Name                                 The Moisturizing Soft Cream
#   Price                                                        175
#   Rank                                                         3.8
#   Ingredients    Algae (Seaweed) Extract, Cyclopentasiloxane, P...
#   Combination                                                    1
#   Dry                                                            1
#   Normal                                                         1
#   Oily                                                           1
#   Sensitive                                                      1
#   X                                                        130.523
#   Y                                                        21.7864
#   Name: 3, dtype: object, 134.44306036095094)]

# %%
#installing transformers for sentiment analysis using BERT
# !pip install transformers
# !pip install tensorflow
from transformers import BertTokenizer, TFBertForSequenceClassification
from transformers import InputExample, InputFeatures

#initializing the base pretrained classifier
SentimentClassifier = TFBertForSequenceClassification.from_pretrained("bert-base-uncased")
#initializing the base pretrained tokenizer 
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
SentimentClassifier.summary()
# Out:
# Collecting transformers
#   Downloading transformers-4.12.3-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 8.8 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 46.0 MB/s
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.1.1-py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 5.9 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.62.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.8.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.3.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.0)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 42.0 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 52.7 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.1.1 pyyaml-6.0 sacremoses-0.0.46 tokenizers-0.10.3 transformers-4.12.3
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.7/dist-packages (2.6.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.37.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.41.0)
# Requirement already satisfied: clang~=5.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (5.0)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.12.0)
# Requirement already satisfied: tensorboard~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.6.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.37.0)
# Requirement already satisfied: h5py~=3.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.12)
# Requirement already satisfied: tensorflow-estimator~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.6.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: keras~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.6.0)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: numpy~=1.19.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.19.5)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py~=3.1.0->tensorflow) (1.5.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow) (3.3.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow) (1.0.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow) (1.35.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow) (2.23.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow) (57.4.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow) (1.8.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (1.3.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow) (4.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (3.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard~=2.6->tensorflow) (3.6.0)
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/511M [00:00<?, ?B/s]
# All model checkpoint layers were used when initializing TFBertForSequenceClassification.
#
# Some layers of TFBertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/455k [00:00<?, ?B/s]
# Model: "tf_bert_for_sequence_classification"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bert (TFBertMainLayer)       multiple                  109482240
# _________________________________________________________________
# dropout_37 (Dropout)         multiple                  0
# _________________________________________________________________
# classifier (Dense)           multiple                  1538
# =================================================================
# Total params: 109,483,778
# Trainable params: 109,483,778
# Non-trainable params: 0
# _________________________________________________________________

# %%
#these are the reviews just for testing the classification (this will not be present in the final myntra code)
pred_sentences = ['This was an awesome product. I bought it twice my time using this beautiful product if I have known it was this good','One of the worst product of all time, i am unable to understand why i bought this',"The color looks amazing on all indian skin tones. Me & my mom - we both use the same shade. I'm fair and she is wheatish yet this color suits both of us. Specially when paired with blue & yellow it just rocks. I assure you will stand out of the croud after using this. Iv been in love with the shade for 3 years now ","Wow I loved this shade and like the brand also.... And my first expeiance with myntra was fabulous good packaging and in time delivery.. Thank u so much myntra","In love with the colour. It's a pretty fuchsia pink that would suit almost all skin tones. As the name suggests, it is creamy matte in formula. Happy with the purchase.","I loved the color of lipstick it's super brighter and shiner too...Without any doubt bought it." ,"I loved so much colour,texture & creamy matte formula of lipstick...", "Little damaged from top side","Very nice colour..go for it","It's like red and pink mix Russia I love it","Wow so good nyc" ,"The lipstick is broken ...color was good but bar was broken...I want to change it.","Not good","I ordered this lipstick to gift someone. I opened it just yesterday..that was so in bad condition..it was broken..bad experience", "So worst quality . I didnt expect this cheap quality frm Maybelline like big brand. Its just like local market 20 rs. type lipstick. Literally soooooo HORRIBLE","Old product. Expiry is in next year Apr. 50% shelf life is gone."]

# %%
#randomly shuffling the reviews
import random
random.shuffle(pred_sentences)

# %%
#taking the sample to test the system from the Sorted list (from TSNE similarity)
sample = Sorted[1:9]

# %%
len(sample)
i=0
count=0
#Assigning 2 reviews for each product
while(i+1<(8*2)):
  reviews={"Reviews": [pred_sentences[i],pred_sentences[i+1]]}
  temp=list(sample[count])
  temp.append(reviews)
  sample[count] = temp
  count+=1
  i+=2

# %%
#Loading the weights for Sentiment Analysis that we trained and saved
SentimentClassifier.load_weights("/content/drive/MyDrive/Myntra_Hackerramp/Beauty_Recommendation/Sentiment_Analysis_Weights/SentimentAnalysis.hdf5")

# %%
import tensorflow as tf
# initializing ScoreGenerated for storing the products in sorted order (High score first)
# Formula:  CriticalScore = ConfidenceScore*10000 + ((Rating*1000)-(Similarity*1000)) 
# Here: ConfidenceScore - Probability of SentimentClassifier Whether it is Positive or Negative
# Here: Rating - Overall Rating of product in the website (between 0 and 5)
# Here: Similarity - Distance between this product and reference product  
ScoreGenerated = []
for k in range(0,len(sample)):
  #Criticals=[]
  CriticalScore=0
  RatingandSimilarity=sample[0][0][4]*1000-sample[k][1]*1000
  tf_batch = tokenizer(sample[k][2]['Reviews'], max_length=128, padding=True, truncation=True, return_tensors='tf')
  tf_outputs = SentimentClassifier(tf_batch)
  tf_predictions = tf.nn.softmax(tf_outputs[0], axis=-1)
  labels = ['Negative','Positive']
  label = tf.argmax(tf_predictions, axis=1)
  label = label.numpy()
  for i in range(len(sample[k][2]['Reviews'])):
    if(labels[label[i]] == "Positive"):
      print("Points: "+str(int(tf_predictions[i][label[i]] * 10000)))
      CriticalScore+=int(tf_predictions[i][label[i]] * 10000)
      print(sample[k][2]['Reviews'][i], ": \n", labels[label[i]],"\n Confidence : ",tf_predictions[i][label[i]])
    else:
      print("Points: "+str((-1)*int(tf_predictions[i][label[i]]*10000)))
      CriticalScore+=(-1)*int(tf_predictions[i][label[i]]*10000)
      print(sample[k][2]['Reviews'][i], ": \n", labels[label[i]],"\n Confidence : ",tf_predictions[i][label[i]])
  ScoreGenerated.append((CriticalScore+RatingandSimilarity, sample[k]))
# Out:
# Points: 6330
# Little damaged from top side :
#  Positive
#  Confidence :  tf.Tensor(0.63301265, shape=(), dtype=float32)
# Points: 5904
# Old product. Expiry is in next year Apr. 50% shelf life is gone. :
#  Positive
#  Confidence :  tf.Tensor(0.59043205, shape=(), dtype=float32)
# Points: 9985
# I loved the color of lipstick it's super brighter and shiner too...Without any doubt bought it. :
#  Positive
#  Confidence :  tf.Tensor(0.99858034, shape=(), dtype=float32)
# Points: -9945
# I ordered this lipstick to gift someone. I opened it just yesterday..that was so in bad condition..it was broken..bad experience :
#  Negative
#  Confidence :  tf.Tensor(0.9945831, shape=(), dtype=float32)
# Points: 9992
# This was an awesome product. I bought it twice my time using this beautiful product if I have known it was this good :
#  Positive
#  Confidence :  tf.Tensor(0.9992362, shape=(), dtype=float32)
# Points: 9984
# In love with the colour. It's a pretty fuchsia pink that would suit almost all skin tones. As the name suggests, it is creamy matte in formula. Happy with the purchase. :
#  Positive
#  Confidence :  tf.Tensor(0.99841404, shape=(), dtype=float32)
# Points: 9976
# Wow so good nyc :
#  Positive
#  Confidence :  tf.Tensor(0.9976271, shape=(), dtype=float32)
# Points: 9987
# It's like red and pink mix Russia I love it :
#  Positive
#  Confidence :  tf.Tensor(0.99876815, shape=(), dtype=float32)
# Points: -8076
# The lipstick is broken ...color was good but bar was broken...I want to change it. :
#  Negative
#  Confidence :  tf.Tensor(0.80768436, shape=(), dtype=float32)
# Points: -9991
# One of the worst product of all time, i am unable to understand why i bought this :
#  Negative
#  Confidence :  tf.Tensor(0.9991605, shape=(), dtype=float32)
# Points: 9977
# I loved so much colour,texture & creamy matte formula of lipstick... :
#  Positive
#  Confidence :  tf.Tensor(0.99779725, shape=(), dtype=float32)
# Points: 9991
# The color looks amazing on all indian skin tones. Me & my mom - we both use the same shade. I'm fair and she is wheatish yet this color suits both of us. Specially when paired with blue & yellow it just rocks. I assure you will stand out of the croud after using this. Iv been in love with the shade for 3 years now  :
#  Positive
#  Confidence :  tf.Tensor(0.99914205, shape=(), dtype=float32)
# Points: -9991
# So worst quality . I didnt expect this cheap quality frm Maybelline like big brand. Its just like local market 20 rs. type lipstick. Literally soooooo HORRIBLE :
#  Negative
#  Confidence :  tf.Tensor(0.99914956, shape=(), dtype=float32)
# Points: -9967
# Not good :
#  Negative
#  Confidence :  tf.Tensor(0.9967263, shape=(), dtype=float32)
# Points: 9980
# Very nice colour..go for it :
#  Positive
#  Confidence :  tf.Tensor(0.9980596, shape=(), dtype=float32)
# Points: 9992
# Wow I loved this shade and like the brand also.... And my first expeiance with myntra was fabulous good packaging and in time delivery.. Thank u so much myntra :
#  Positive
#  Confidence :  tf.Tensor(0.99920195, shape=(), dtype=float32)

# %%
# Defining sorting function for sorting the list using first variable
def sortwithFirst(val):
    return val[0] 
#Sorting using the defined function
ScoreGenerated.sort(key=sortwithFirst,reverse=True)

# %%
ScoreGenerated
